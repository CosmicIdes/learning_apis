# %% [markdown]
# # Learning APIs with fox images

# %%
import requests

# %%
response = requests.get("https://randomfox.ca/floof/")

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.text)
# Out:
# {"image":"https:\/\/randomfox.ca\/images\/33.jpg","link":"https:\/\/randomfox.ca\/?i=33"}

# %%
print(response.json())
#returns a dictionary that can then be used
# Out:
# {'image': 'https://randomfox.ca/images/33.jpg', 'link': 'https://randomfox.ca/?i=33'}

# %%
fox = response.json()
print(fox['image'])
# Out:
# https://randomfox.ca/images/33.jpg
